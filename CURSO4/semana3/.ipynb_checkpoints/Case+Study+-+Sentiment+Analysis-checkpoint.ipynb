# %% [markdown]
# ---
#
# _You are currently looking at **version 1.0** of this notebook. To download notebooks and datafiles, as well as get help on Jupyter notebooks in the Coursera platform, visit the [Jupyter Notebook FAQ](https://www.coursera.org/learn/python-text-mining/resources/d9pwm) course resource._
#
# ---

# %% [markdown]
# *Note: Some of the cells in this notebook are computationally expensive. To reduce runtime, this notebook is using a subset of the data.*

# %% [markdown]
# # Case Study: Sentiment Analysis

# %% [markdown]
# ### Data Prep

# %%
import pandas as pd
import numpy as np

# Read in the data
df = pd.read_csv('Amazon_Unlocked_Mobile.csv')

# Sample the data to speed up computation
# Comment out this line to match with lecture
df = df.sample(frac=0.1, random_state=10)

df.head()
# Out:
#                                              Product Name Brand Name   Price  \
# 394349  Sony XPERIA Z2 D6503 FACTORY UNLOCKED Internat...        NaN  244.95
# 34377       Apple iPhone 5c 8GB (Pink) - Verizon Wireless      Apple  194.99
# 248521  Motorola Droid RAZR MAXX XT912 M Verizon Smart...   Motorola  174.99
# 167661  CNPGD [U.S. Office Extended Warranty] Smartwat...      CNPGD   49.99
# 73287   Apple iPhone 7 Unlocked Phone 256 GB - US Vers...      Apple  922.00
#
#         Rating                                            Reviews  \
# 394349       5  Very good one! Better than Samsung S and iphon...
# 34377        1  The phone needed a SIM card, would have been n...
# 248521       5  I was 3 months away from my upgrade and my Str...
# 167661       1                     an experience i want to forget
# 73287        5        GREAT PHONE WORK ACCORDING MY EXPECTATIONS.
#
#         Review Votes
# 394349           0.0
# 34377            1.0
# 248521           3.0
# 167661           0.0
# 73287            1.0

# %%
# Drop missing values
df.dropna(inplace=True)

# Remove any 'neutral' ratings equal to 3
df = df[df['Rating'] != 3]

# Encode 4s and 5s as 1 (rated positively)
# Encode 1s and 2s as 0 (rated poorly)
df['Positively Rated'] = np.where(df['Rating'] > 3, 1, 0)
df.head(10)
# Out:
#                                              Product Name  Brand Name   Price  \
# 34377       Apple iPhone 5c 8GB (Pink) - Verizon Wireless       Apple  194.99
# 248521  Motorola Droid RAZR MAXX XT912 M Verizon Smart...    Motorola  174.99
# 167661  CNPGD [U.S. Office Extended Warranty] Smartwat...       CNPGD   49.99
# 73287   Apple iPhone 7 Unlocked Phone 256 GB - US Vers...       Apple  922.00
# 277158  Nokia N8 Unlocked GSM Touch Screen Phone Featu...       Nokia   95.00
# 100311  Blackberry Torch 2 9810 Unlocked Phone with 1....  BlackBerry   77.49
# 251669  Motorola Moto E (1st Generation) - Black - 4 G...    Motorola   89.99
# 279878  OtterBox 77-29864 Defender Series Hybrid Case ...    OtterBox    9.99
# 406017  Verizon HTC Rezound 4G Android Smarphone - 8MP...         HTC   74.99
# 302567  RCA M1 Unlocked Cell Phone, Dual Sim, 5Mp Came...         RCA  159.99
#
#         Rating                                            Reviews  \
# 34377        1  The phone needed a SIM card, would have been n...
# 248521       5  I was 3 months away from my upgrade and my Str...
# 167661       1                     an experience i want to forget
# 73287        5        GREAT PHONE WORK ACCORDING MY EXPECTATIONS.
# 277158       5  I fell in love with this phone because it did ...
# 100311       5  I am pleased with this Blackberry phone! The p...
# 251669       5  Great product, best value for money smartphone...
# 279878       5          I've bought 3 no problems. Fast delivery.
# 406017       4                       Great phone for the price...
# 302567       5  My mom is not good with new technoloy but this...
#
#         Review Votes  Positively Rated
# 34377            1.0                 0
# 248521           3.0                 1
# 167661           0.0                 0
# 73287            1.0                 1
# 277158           0.0                 1
# 100311           0.0                 1
# 251669           0.0                 1
# 279878           0.0                 1
# 406017           0.0                 1
# 302567           4.0                 1

# %%
# Most ratings are positive
df['Positively Rated'].mean()
# Out:
# 0.7471776686078667

# %%
from sklearn.model_selection import train_test_split

# Split data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(df['Reviews'], 
                                                    df['Positively Rated'], 
                                                    random_state=0)

# %%
print('X_train first entry:\n\n', X_train.iloc[0])
print('\n\nX_train shape: ', X_train.shape)
# Out:
# X_train first entry:
#
#  Everything about it is awesome!
#
#
# X_train shape:  (23052,)
# ['Everything about it is awesome!',
#  'I bought this phone in July of 2015, and I loved it so much, but I do speak of it in the past tense for a reason. The beginning of June 2016 it died on me. The phone is now just boot loops every time I try to turn it on. I tried to get ahold of the customer service, and they tried to talk me through resetting it through the boot menu(which I had already done), and the call dropped, and they never called me back. I would love to give it a better review, but less then a year later it is as good as a brick.',
#  'Small and very light, simple, when just a phone is needed. Amazing battery life.',
#  'Awesome phone',
#  "The phone is just as described. Looks sleek and all. I bought this phone 3 weeks ago, and after 2 weeks i got some glitches , wouldnt read my sim card out of nowherr, and the battery drained really quickly. Just from one day to the next. I contacted customer service and they sent me a new one right away. The service was great. I ended up putting a factory reset on the first phone and now it seems to work just fine. Im sending back the first one and continuing with the second one they sent me. I really like the phone. Works great. I think it was that particular one that went a bit mad. Anyways. Will update with the new one in a month or two.Update:6 months later and the camera quit working. I've tried everything. Im dissapointed. A camera is a must have for me on a phone. Im purchasing a new phone, but it won't be a sony. Had too many issues with one phone within 6 months.",
#  'Very Good',
#  'Good telephone and very stylish and slim. Battery is amazing. Good update to Android 6.0.1. However, pictures should be better...missing the pictures of my LG G4. Also the menu...missing options to customizise the phone, that I can find in other Android phones.',
#  'excellent seller. I recommend 100%',
#  "My old LG android phone was failed to update OS and broken. So I bought something different from LG. This Samsung works OK. It's worth for my money.",
#  "I've had a Samsung Galaxy S2, S3, and S4. I understand some people like big phones, however, that's not my preference. That's why when the S5 came out, I started looking for something else. Then I found the Sony's Xperia Z Compact phones. I had originally wanted the Z3+ (Z4 elsewhere), but right when I was about to buy it, the Z5 Compact came out. While it's not available in the US via normal retailers, I was able to get a warranty for it via SquareTrade. So that made it a no brainer for me. I've had it for a few months now and I'm still loving it.",
#  'This Phone was as described New and the service was excellent and fast.. I was looking for this phone and Im glad I found it.. Lets get something clear, this is not a smartphone so if your looking for one they have them available, just make sure you read the technical details and product details that they provide you with..',
#  'This is a fun little device. It is a solid cell phone, acts as a mini pc able to store plenty of data on 4 g mini cards you can buy for it. I have hundreds of tracks of music on the one I bought for it so far. Video eats up enough data space I can see carrying a pouch of cards with favored vids on them or just one and a smart pad with a bigger card and using the blue tooth to swap files as needed.It isnt too bulky though I am a 6 foot tall american male, I can see smaller framed men and women finding it perhaps too big.I paired mine with a nemesis leather watch band also found here on amazon and have nothing but love for the combo after a month of regular wear',
#  'It works very well',
#  'My daughter just love her gift. Not an apple fan but the price was good. Also got the 5 for my son.',
#  'Good',
#  'Excellent!',
#  'Excelent phone',
#  'It is a good device. Go for it.',
#  'Greetings! the phone did not come unlocked as it appears in the publication.',
#  'Muy bueno!!',
#  'Very useful',
#  "this is the second of these phones. first one got wet. texting, especially in T9 takes time for the phone to know how you talk, lots of drop down menus to choose your word from. that gets annoying but the more you text ...the less they pop up. For those out there who don't want to use a smart phone yet...this is the next best thing. I have noticed among Crux users that they are all a little different...some slide really easy, while others are slightly stiff. I don't mind the stiff sliding ones because then it doesn't accidently slide up and call someone or start randomly start playing your music. we've had ours for two years and more and have not upgraded yet. no rush.",
#  'Apparently BlU phones in general are junk made to be disposable in a few months. Bought 1st BlU phone, lasted about 7 months and died. Bought this phone in august 2014 to replace it. Guess what? It died 2 days ago, just past the 6 month mark. This means I have spent over $350 on Blu phones in just over a year. Might as well buy a better phone to start with. You say warranty? read the fine print closely. Sent in the first phone, but even though it had just died and would not boot, it was claimed to be "damaged" and would cost more to fix than buying another one. The phone was never misused or abused. Useless warranty.',
#  'Good basic phone; perfect for those who want texting capabilities without an Internet-connected smartphone.Like another reviewer experienced, this phone came with "PP" appended to the model number, but a little programming/reset help from Verizon\'s customer service 800# and we were up and running shortly.',
#  "The cellphone overheat a lot! I can't watch a movie, talk or record for more than 20 minutes, and I did without the cover. That's very bad for a tremendous cellphone.",
#  'I got this phone 4 months ago. Today it went to the start up screen and strayed locked there. I have tried everything to make it work. Removed battery, removed SIM card. Tried doing what vids on YouTube told me to do. Nothing has worked. Now I am without a phone.',
#  'thats a good phone',
#  "Awesome little phone, can't beat for the price",
#  'Works great!',
#  'It is nice to have handy. This watch is fun after I added attraction from bluetooth it handles good. Now I have movies on the go with music/phone/videos.',
#  'the Worst dont buy it Please',
#  'Was as expected',
#  'great product',
#  "I totally recomend you this cellphone. Maybe it's kinda expensive, but its worth it. Seller did great. And sent the product at time",
#  "Not quite what I expected I thought it was a smartwatch it's more like a basic phone which doesn't have any smart capabilities. fun to play with or wouldn't use it as my regular phone call quality is very quiet the headphones that came with it is low quality and very quiet had to search a long time to find the right program to pair with my phone sorry to say I forgot what that program is while writing the review",
#  'cute phone and fast deliver',
#  "My only qualm is the diminished sound from the speaker. It makes it a bit hard to get noticed when you're in the other room. Except that, the device is beautiful. Google created this device for hacking and that is what it is meant for. The battery life isn't bad. I can have it go all day without having to charge it.With the advent of Google Butter on Jelly Bean, the performance has escalated. We can only presume to go further from here. Truly worth the cost. Thanks a lot Google! and Samsung of course!",
#  "P.o.s!!!! Falsely advertise it as having 4gb of internal storage. You can not download apps because it does not have the storage they tell you it has. This is a clone of the Z18 android but in a different case. Don't buy unless you have money to throw away.POS.",
#  'I like',
#  'VERY nice product..Would recommend to buy..',
#  "Couldn't even tell us was used, not a scratch. Would order again and again",
#  'Very nice.',
#  'Simply excellent, very responsive to touch, easy to setup (mind you I am a computer geek, your mileage may vary)the Good -1) Small2) wifi and bluetooth enabled3) Easy to connect to the net and install apps via the wifi4) Google, Facebook, Youtube etc already setup and easy to access5) Good quality camera6) Good quality screen7) Screen protector included8) Decent music quality with the included headphones9) Comes with 2GB memory card!the Bad -1) Charger included is a bit clunky (got around this by using my PC to charge it instead)2) Small!Recommended apps - Angry Birds!:-)',
#  "Got this for my daughter for her birthday, was listed as good condition but it was practically brand new just didn't have a box. Super fast shipping! Thank you",
#  'Does not work well!!! Does not receive messages, does not notify, does not allow for calls, etc. In order for it to function, you need to take out the phone which defeats the purpose of the watch. Do not recommend!',
#  "I love my new Iphone. Then it's in my fav color.",
#  'MUY BUENO',
#  'It us sticking sometimes.',
#  'This phone was derived like new, could not see the difference between a new phone and this one. I have been using it for more than 6 months now and I have no complains.',
#  "This phone was advertised as unlocked, but it is not. It works only with T-Mobile SIM cards. I will attempt to get it unlocked, but will have to pay extra for this. The phone itself is fine, but the product description should say it's a T-Mobile phone, not an unlocked one.",
#  'Only can get 2G...my fault for not reading fine print, but barely works off Wifi.',
#  'Great phone when it worked. I loved everything about this phone but one day it died and I put it on the charger and it never turned back on.😠',
#  'Love for my daughter didnt have to have a plan',
#  'its a good product',
#  'Nice phone. Not the greatest in low light though.',
#  "Fantastic in almost every way. Works flawlessly on AT&T in U.S.After 4 plus weeks of use.My wife and one of my daughters has the iPhone 6. Ran it side by side with my daughters And it Ran just as fast.In most cases of downloaded faster And was never slower.I only wish this phone Was 1080p instead of 720pBut other than that I love everything about it. also i really cant tell unless it next to my other daughters samsung s6. I'm coming off of a HTC m8 Into this phone And couldn't be happier. I do not play a lot of games with the couple I have seem to do really well. The aesthetics, fit, and finish All seem to be on par With the two big Companies.(Samsung Apple). So far after 4 weeks I have not went Less than at least three days on a charge. And since it was a new toy the first few days with heavy use. The battery in this thing is unbelievable. Me personally, I'm not say What's most up-to-date snob. So the Android 4.4 is fine. However, I did see that there is the 5.0 update available for it Might try that out And perhaps repost afterwards.The sheer size of the phone is a bit cumbersome at first But Become second nature within days. I do love The six plus inch screen As I'm getting older my vision isnt as good as it used to be. To be honest I would be a little bit happier with say 5.5 in. screen. i was glad to see a few decent cases for this phone, which is another reason i assured myself to pick tgis phone up. the price certainly didnt hurt either. I have not yet experienced any forcestops or Force closes, nor Any glitches of any kind. It has been flawless thus far. Camera seems to do really wellWhen blowing them up on the computer.The external speaker is not quite as loud as I would like but I link my phone to a wireless speaker anyway so its no issue.Hope this has helped you some And I would highly recommend this phone to absolutely anybody. I am Excited About potentially switching the rest of the family to one of these and start saving me hundreds of dollars a year Because right now They all have $800 phones And this one works every bit as good as any of those in every way you can imagine except screen resolutionEDIT;Now on month 5 with the huawei ascend mate 2 and im on at&t network with it here in ohio. Nothing has changed at all with speed, dependability, and my happiness. There has been no glitches or hiccups of any kind. Im officially a Huawei customer for life. This phone has been fantastic. Reception on this device is betr then what i had on my samsung s5 or my htc one m7. I still havent tooken advantage of the dual sim card option, so i cant comment on that, but i will say that im a contractor in columbus ohio and can b quite rough on my devices but to my surprise this phone has taken a beating and not a problem one with functionallity. I have dropped it from 10 ft over concrete. It hit so hard that the case flew off and so far away it took a couple min to find it. Yes, it is scatched up, but works just as good as ever with no real damage to the screen. Dont get me wrong. This is not a ruggedized phone. Maybe i was lucky. Most likely its just a testiment to the build quality. Very impressed none the less.Again, i paid for this phone. I did not receive it for a review. Im a honest to goodness customer who shelled out 200 bucks for this and has been very happy for it. Hope this helps all of u.",
#  "The phone looks really good, it has everything that it needs to work properly BUT:1. They haven't send the Lollipop as they said they will2. When I conect the headphones my cellphone turns off3. When is charging I can barrely write or open my apps4. Sometimes I want to open the camera and I have to do to my intragram open the camera there and then go to my regular camera to open it.This is a good phone but without the update it barrely work properly.",
#  'el telefono bold 9780 es muy completo se lo recomiendo tiene muchas funciones las fotos y los videos se ven muy bueno me encanta mucho este telefono demaciado bello',
#  'Just what they said, is exactly what it is. Works GREAT..............',
#  "This phone is probably the only phone in the word that has been reviewed numerous times in numerous sites. So, I will skip the review part. It has great features and works very well. It is a true workhorse. Even though it doesn't bug me, the only downside is that it is slow at times. Not a a big deal but wanted to point out some flaw.",
#  'the phone cuts on and off, but without a warranty there is nothing you can do',
#  'I was happy to get this till an update failed so now just have to deal with it for awhile now possibly wait til tomorrow or something to reboot it',
#  'not to bad once you play with it a bit. i got it to use as an mp3 player well working around the house that i wont need head phones for and play via a blue tooth speaker. it wont sync and also i have to get a new bar for the watch band witch came (new today still in box) broken',
#  'on time ,no problem .',
#  'It is an excellent phone, fast, and very light, meets my expectations, is what I expected, the battery lasts quite, I spent almost a whole day playing and browsing and does not completely download.',
#  'worse phone ever!!! do not buy...I bought two and I want a refund!!!',
#  '😀',
#  'broke in the 1st week',
#  'Just like my old one. And the case is my favorite colo . Prefect!',
#  'love it',
#  'I recommend it',
#  "This is my first blu phone, and I must admit I'm pleasently surprised. Big bright screen, beautiful design, and good power for 200 bucks.",
#  'great phone...great buy...not disappointed',
#  'good good good five stars',
#  'excelente',
#  'Nice phone',
#  'excellent Item',
#  "I love this phone, it's exactly what I wanted. I also love that it's pink. I was debating between the S6 and S7, but the lack of expandable memory for the S6 and design for S7 didnt convince me.It has the basic features you could ask for, plus a fingerprint scan and google pay.I only have to charge once and the battery lasts me all day, A BIG PLUS compared to my old phone.This is not a 4G phone, it's an H+...overall I can't tell the difference. It all comes down to your service provider. Some places get better coverage than others.This is an international model and the charger is not meant for the US, but the company that I bought this from Mobile Front sent me an adapter.",
#  "The phone took LycaMobile SIM card and works great in NYCity. The charger port is mini USB, compatible with all my other family's phones which is very convenient. Wallpaper can not be changed by I like the flower. Ring volume can be changed only through UI, but I can easily toggle between Sound and Silent modes. Simple and efficient for inexpensive calling.",
#  'didnt work',
#  'Nit what I expected.',
#  "Got my phone June 19th and I love it I haven't had any issues with the phone it is the perfect phone for me so satisfied and glad I bought this phone",
#  'Great form factor, incredible battery. Over 150 hours of usage before running out of juice. Only takes 1hour to recharge. And cheap to boot. What else can say? Best and latest Android OS... I pity people who buy iPhones.',
#  'This phone is great, and the price is even better. I debated this purchase for a while, and finally went through with it. No regrets with that decision.',
#  "I used this phone for a few months. It looked good and the physical keyboard was very useful. Unfortunately the phone (OS) crashed very often what became extremely annoying. After the OS crash you have to remove the battery and restart the system. Once I overslept and was late to work just because the system froze in the night and the alarm didn't ring in the morning.What is really unbelievable is the fact there is no firmware update available for this model. It just shows how much LG cares about the functionality and reliability of their devices and customers' satisfaction. I dumped this phone and got myself a cool new Android handset which most importantly just works. I'm very disappointed with LG and will stay away from their products. I sincerely advise you the same.",
#  'Very Good Buy, Thank You .',
#  'Great phone. I like googles case too.',
#  'Excellent product. It looked brand new and worked like a charm. No complaints so far.',
#  'keep getting froze, very slow respond. Screen becoming completely blank then had to reboot or restart. Phone also getting hot and battery runs out fast. The phone looks very nice and if it works properly then its worth of the money. May be this phone is defective in particular.',
#  'Good',
#  "I'm in love with the otterbox.",
#  'EXCELLENT ITEM',
#  'Nokia C6 Unlocked GSM Phone with Easy E-mail Setup, Side-Sliding Touchscreen, QWERTY, 5 MP Camera, and Free Ovi Maps Navigation (Black)',
#  'Terrible Phone I had it for maybe 3 weeks then it just stopped working and the screen was basically falling off when I got it.',
#  'great product',
#  "Apparently this is an issue with this phone and can be fixed by a factory reset but since it's unlocked I'm out of luck. I've tried to contact seller for help no response, so I'll be sending phone back. (Not my network because phone has full service )",
#  'Phone received OK! Nice phone!',
#  'cool;',
#  'Had one before for my S3 which I dropped many times on concrete and a few times from upwards of 15 feet high. No damage ever to the phone.',
#  'arrived early, need to reboot almost daily to keep signal and updates',
#  'The best option between price and perfomance',
#  "Stupid that it wasn't from the USA because if anything happens damage wise the 1 year limited warranty isn't effective",
#  'used this for a year it worked well, but would lag at times maybe due to small RAM.',
#  'It is a experience phone.',
#  'the smarphone not meet my expectations because it never connected in LTE bands promoted on Amazon, so want to return the equipment to amazon and refund my money . I know what the next step for the refund.',
#  'For the price the phone is great! Looks good, good size, takes good pictures, easy to use. Very similar to a samsung device.',
#  "I can't get the thing to sync with my phone. I even watched several Youtube videos on how to do it and still can't figure it out. Can't find the sound to turn it down or off. Can't pull up the apps section most of the time. Sending it back. Don't waste your money!",
#  'I BOUGHT THIS $99.99 PHONE TO TRY AND FINISH UP MY 8 MONTH CONTRACT WITH VERIZON. I BABY MY PHONES AND NEVER EVER DROP THEM. THIS PHONE COMPLETELY CRAPPED OUT IN 3 MONTHS. P.O.S. DO NOT BUY ! ! ! ! !',
#  "So I have been waiting for this phone to be available for a LONG time and am so glad it stands up to virtually all my expectations. If only they could have made it a LITTLE smaller!So the first thing I want to note is that this DOES indeed work with Tmobile with no manual setup or configuration - I just went into the Tmobile store, told them I have a phone I want to activate, they gave me the nano-SIM which I put in, turned the phone on and everything worked including MMS messages - super simple!I tested Internet speed while cell reception was on 2 out of 4 bars LTE, and was getting an average of 4 Mbps.Even though T-Mobile's wifi calling won't work, I just installed the updated hangouts dialer app and I'm all set to make calls when off-network and on only wifi from my free Google number.I don't have very big hands, but can still hold use this with only one hand which is my main objective, and it looks great too! Front speakers are great and you can really tell the difference in sound when you turn the phone sideways and allow your ears to pick up the stereo effect.In regards to the camera, the automatic mode is great. However the maximum advertised resolution for both the front and back cameras is only achieved in 4:3, not 16:9 to match the wide screen, though 16:9 is available with slightly smaller resolutions.Battery life is great with stamina mode - after a full day of being connected to my Bluetooth and typical handful of calls and several texts though leaving Internet off, I got home at 5:30 with still 93% remaining!No overheating issues as some have mentioned - it was barely even warm after playing a graphically intense game for over 20 minutes +Overall very happy with this phone, and I have high hopes for durability.",
#  'Great phone. Own both the edge and s7 and would recommend the regular s7 over the edge because of the annoying inputs you get just by holding the phone due to the screen wrapping on the edges. Yet to get a case for the edge since I prefer no case but will have to try one as I heard it helps fix the accidental touches greatly. The s7 feels great and boasts impressive hardware and a 1440p screen. The battery is also decent at 3000 mah. Definitely one of the best smart phones on the market and easily outshines the iPhone',
#  "The title clearly says its unlocked, but when I inserted my sim card it received no signal from my carrier. I went to the sim card app and it asked me to enter a pin code. I tried 0000 1234 but no success. I couldn't use the phone so I'm sending it back. What a waste of time.",
#  'Great phone. Changed me to an apple person.',
#  'Sent phone to my sister in law in Jamaica. Phone not unlocked and having sim card issues.',
#  'I am 100% satisfied with my purchases thank you very much',
#  "The phone is great except the battery isn't very good.",
#  'Arrived brand new in the box as described, best phone for the money.',
#  'Good deal for an 5C iPhone. As advertise by the vendor. iPhone was in great conditions. It came with Original box, USB cable for the charger and the headphones. The only small complain was that the phone came with a not good SIM Card, which was provided at the Sprint Store. Great price for the item. Vendor was easy to contact and get a feedback. Recommend this vendor !',
#  'Reliable and fast.',
#  'the phone does not catch signal, I need a refund please contact me, I need to help me',
#  "Great phone. I'm in love with it",
#  "Phone's battery will not charge with any cable. I have to switch the battery out of a broken phone, charge the battery up inside of the broken phone, and then place the battery back inside of this phone.",
#  'A thin and light phone with a nice appearance, a powerful core, a impressive 13M-Pixel lens and a gorgeous touchscreen. The hardware is perfect. But it has a System of a mixture of English, traditional and simplified Chinese, and has pre-installed too many useless software which need to be removed one by one.The attached earphone is poor in both performance and appearance.',
#  'Super phone and works great with Cricket.',
#  'love it. It is working really well. Will certainly recommend this phone to all my friends. Prompt service received from the supplier. Thanks',
#  "I brought this phone last 5 days ago and then this morning , I can't open my phone, it's screen keep screen. I will return it or SELLER NEED TO FIX it.",
#  'If your hobby is photography and you want to take any important event in your life, this is yor phone. I owned before this one, a Nokia 6020 and 6131 phones with VGA and 1.3 MP cameras respectively, but when compared, the SE 790a is the winner. It is really a little point and shoot camera with a phone atached. Specially for indoor/night pictures, the flash is top; even if you are in total darkness the AF work and you can use the flash in auto mode (not red eye reduction) and help it with a separetely slave flash unit for better lighting. Is good idea to order with the phone the car charger, so you will be always loaded, and the 512 MB memory card, because the phone only has a 64 aditional card plus the inside memory wich is not enough; both items has free shipping from Amazon. On the other side the standard headset could not be used at the same time with the charger, so if you plane to do this you will need the special headset for this purpose, and it is quite expensive. Another cons are the very low volume on the rear speaker: you could not hear a conversation and write a note. If you use the calendar option frecuently and you want the phone reminder you any event weekly, for example, it is a paine, because it did not have this function. You should copy the name of the event and change the date for every day you want it work, again and again....Something Sony Ericsson should do for improve, is to put some type of locking device, a button perharps, for the lens cover, so it will not slide in the wrong moment. Anyway compared with the Nokia N73 for example, wich is the closest competitor, the Sony Ericsson win, because has much better price. Vicente.',
#  'excellent seller, the article described was received. All good',
#  "Had to return because it didn't work with my provider. Very quick refund..",
#  'buenas noches la compra todo fue muy rapido y sin ningun problama y en excelentes condiciones y llego a tiempo gracias',
#  "phone looks exactly like the picture. has small scratches on the back but it came with a case and a screen protector which wasn't bad. y'all should get this phone. PLUS ITS 64GB",
#  'It arrived much, much later than i had expected to give it to someone for a gift!',
#  'good work great',
#  "Being the first time to buy abroad, online and TDC had many questions and concerns, but turned out to be good and rewarding experience. I could buy a good cell phone, here are expensive. SHOPEBEST announcement proves true, it is released (unlocked) internationally (because here in Venezuela I can use it without any problem) is white and is 8Gb, excellent operating system, camera, applications and fast. Although I have to narrow, since I got it a few weeks ago, me happened because a couple of times off and if you press the power button does not light (I have to remove and replace the battery again) but otherwise no complaints and visually SAMSUNG GALAXY MINI GT-i9195 S4 turns out to be attractive. He sent by SHOPEBEST and Amazon was quick, I'm good without objection, without details and with all that specific in its box.",
#  "Purchased a while ago and was never able to find a case online or instore that actually fit this phone- I will now attribute the fact that my phone is dented, cracked, and scuffed to the lack of case availibility....and not my pure clumsiness. I don't think I'll ever buy a no-name cell phone again. Too many compadability issues. I will be replacing it as soon as I save enough to get a better phone (without contract).",
#  'Excelent',
#  "In realitty, it doesn't even deserve a 1. I can't stand this phone and I feel I just wasted my money.",
#  'Great quality.',
#  'Absolutely beautiful, like all HTC devices .Pros : great camera ,5" screen , latest Android software ,fast CPU ! ,latest gorilla glass, awesome audio through headphones or earbuds massive bass !, I really like the amoled screen less glare in sunlight , SD card slot ! , rapid charge ! , fingerprint scanner pretty cool .amazing camera preforms great in sunlight and the image stabilization is phenomenalCons: No Front Speakers !!??!?!?!?! Why? , speaker volume not as great , amoled screen ( although it\'s better for sunlight it\'s clarity and sharpness are not in par with the LCD screens ) , power button to close to volume buttons you\'ll find yourself turning off you phone more often, needs a protection case ! ( even though it\'s a very slim and gorgeous phone it needs to be protected .slippery due to all metal frame . Average battery life .Conclusion : a great phone nontheless , it\'s not a flag ship phone. the m9 is still king , but for a mid range it\'s very pleasing although I feel like its not mid priced . For the money I expected more ,at least the front speakers but oh well I am still very happy with this phone .HTC A9u 16gb',
#  "I like it....It does all I need. Since, I don't really do much internet on the phone, I can't say how effective it is for that. However, e-mails come up easy. I still have not used the camera but it looks very straight forward. So for everything is good.",
#  "Most disappointed I have ever been with a phone. It wouldn't let me send or receive messages or calls",
#  'Battery v bad',
#  "Worst cellphone I have ever used. It looked cute and worked fine for the first three weeks. And all kinds of problem shows up. After I upgraded the system, I can't access to my cellular data. I found the instruction online and fixed that manually. I can't use my group message at all.Apparently SONY never realized that normal people will group text each other. My music app starts to play by itself out of blue, which gave me couple of embarrassing moments during meetings.Then the screen cracked. Well, that was my fault. I fixed that by spending 170 dollars more on this stupid phone. And then the front camera is broken. Just to make a double down, my text function starts to fail. My screen turned completely black when I am making a phone call.I don't think SONY is even trying to sell their cellphones. I bought it because it's cute. But I can't even use it as a simple cellphone. NEVER ever ever buy this phone.",
#  'so far I thinks this is a good device, the only thing I dont like is when the phone gets hot ( few times) and the battery is eaten, would the engineers some time in this future finish with this kind of issues ? despite that ( and I hate when is happen) is a good phone',
#  'Amazing!!!',
#  'I stopped working two months after getting it.',
#  'Works great good camera runs smoothly and works with my carrier perfectly even this T-Mobile sucks in general',
#  "I wanted something that would run off the CDMA network. Otherwise it's good, but not for me..",
#  'The phone had alot more scratching on then it said. It looks pretty banged up screen is hard to calibrate.',
#  'Great phone at a great price!',
#  'I bought this phone and had it for only four days and it wont charge. this phone was built cheap',
#  'All excellent.',
#  'Great for outdoor enthusiasts and those who are less careful with their phone. Sturdy and reliable. Supports four GSM frequencies making it easy for me to get good coverage everywhere with my carrier.',
#  'Excelente!',
#  'very pleased with this purchase. I was skeptical buying a previously owned iphone but just couldnt see paying full price for a brand new one since we werent eligible for an upgrade yet. It was a gift for my daughter for christmas. It was in such good shape with the box and all, she had no idea it was previously owned.',
#  'Always need to project your electronics and you cant go wrong with OTTERBOX',
#  'Very simple, functions well, does not have a speed dial option which I really miss. Texts and makes calls well, handles the two chips fine.',
#  "It's a good back up phone .battery no bueno no memory",
#  'Big purchase (for me) so I was worried, but all went perfectly...',
#  'Great item',
#  'Overall a very good phone I like how big is it and that I could see the letters. Only one thing is very hard to hear when you are talking on the phone is not as loud.',
#  'bueno',
#  "For the money, the best phone I have ever had. I am not a heavy user of data, thus the ability to log-on when at home or in a hot-spot works great for me. The phone signal capture and clarity are outstanding. I would like to remove many of the included apps, that I will never use and hog the available memory, but the mfg won't allow that, so I just work around it and enjoy the phone. Well made and operates smoothly. I also bought the 2nd Generation, CDMA phone for use in an area where the Att's, T-Mobiles and other GSM purveryors do not cover, contrary to what their coverage maps indicate.",
#  "Claims to be compatible with Verizon and AT&T, Verizon said it isn't compatible.",
#  "Just perfect. Exactly what I expected. I works on T-Mobile USA. For the moment I've just had the h+ but it's really fast.I ordered a SM G900F and I received a SM G900FD (duo sim) which is better for me because I use it in two countries !I love it.",
#  'So far, so good. Its a nice phone',
#  "Great phone. All the BLU phones that I've tried so far have been great phones. This phone is your basic android. It takes decent pictures but the front facing pics are not great.",
#  'Will be returning this. I have a Galaxy S5 and I could not get this to be functional as anything more than a bluetooth speaker for my phone. I downloaded the app that it reccomends, in english and in chinese and still could not get full functionality out of the device. I was very excited about it and I was also very let down.',
#  "Great service and product from World Sellers, brand new, sealed iphone 5s , came with ios 8.1.1 instead of 7, made end of 2014, what's not to like!",
#  'great!',
#  'Received my phone faster than expected. Just what I wanted. The phone has been working just fine. The price was right and I have enjoyed using the phone.',
#  "I bought it used and it was in excellent condition works well charges with no prolem the only problem is that the android operating system is WAY!!!!! Outdated it runs android 2.2 froyo and some start at 2.1 Eclair which means alot of new apps and some bluetooth devices won't work unless somehow you can upgrade to something later.",
#  'bad phone',
#  'GREAT KIND REGUARDS',
#  "I received it just after 3 days of ordering. The box seal was broken, but the phone seemed to be perfect & with all official accessories . Works perfectly on T-Mobile with 4G LTE. It's really fast, slim, sexy looking & durable. Feels soo good in hand. The 12MP camera snaps immersive images & 4K video shooting is just out of the world. It comes with Android 4.4.4 KitKat, it's upgradable to 5.0.2 Lollipop (Only if you are on AT&T). It comes with 32GB memory (not expandable), 25.07GB is usable. All games are running soo smooth with high resolution & multitasking is soo fluent. The speaker is good too. The charging is really fast. The battery life is awesome. I fully charge it at night & it works all day with gaming, surfing & heavy usage (I use Battery Saving Mode). It uses Nano SIM & works on any GSM carrier internationally. I love it in every way.",
#  'Nice',
#  "horrible only worked for 1 month and a half. I ask them to fix it and they told me to send it in. I send it and haven't heard nothing in 2 weeks horrible customer service. The phone was great when it worked.",
#  'Great phone. Great shiping.',
#  'Works as expected!',
#  'I got this as a gift for my roommate. So far, he has been extremely happy with it.',
#  "I like it, I use it for my parents they don't now how to use the modern phone so this one are perfect",
#  'Good',
#  'Purchased this for my mom. She loves it.. came when promised. Arrived in immaculate condition. Flawless.. unlocked as promised, everything works no issues, for $150 best iphone 5 u will get. . Charger included. No complaints',
#  'Thanks Amazon for sending this phone right on time. This item was for my daughter who lives in Peru so she told me that is working great!',
#  "I didn't get my phone",
#  'Love it! :3',
#  "Amazon, Verizon and Samsung are all guilty of leaving out the customer in their decision to leave out the user manual from the purchase order. The custom in left hanging in too many instances where a manual would be of help. Te user is forced to go on line to fined the product's manual and are left to print a 269 page manual or read it on line instead of having it handy for those moments when you need answers.The device is not user friendly in the first place and on line help is well shy of a good mark in putting the customer first instead of any one of the three companies.",
#  'I expected the watch to have all the features. Of. An android device. Be. Able to sync all my important apps via bluetooth but it would only sync a few apps.',
#  "Phone won't hold a charge after 2 months.",
#  'I got this phone for my daughters. Is a perfect little phone and cheap enough in case they break it or lose it. Everything in it works and I was able to use it for cricket wireless with no problems. I got it in pink and white. No problems with battery life or putting in the sim card. Just read the instructions.',
#  'good',
#  'The phone was not what is advertised. The phone lacked Sim card tray. Condition of the phone was worse than advertised.',
#  'Great!',
#  'just ok',
#  'Is an amazing phone!!!! I love it',
#  "My son really wanted this is device and knew the risk when he ordered it. He a fearless kid and I admire his pluck. Sadly, however, this is the product that proves one gets what one pays for. The manual is laughable and the watch's operation is indecipherable. It may work but there's no way to tell between the incomprehensible user interface and useless instructions. Honestly the manual is not entirely without value. We were moved to tears of laughter as we took turns reading it aloud. Obviously, at this price translation, even Google's free translation services were beyond the budget. One must install an app on the phone which immediately and relentlessly spawns requests to install additional, unnecessary apps. I know the idea of an inexpensive smart watch is tempting, like the dangerous yet beautiful song of the sirens, but it must be resisted. This watch will see your hopes dashed upon the rocks.",
#  'Never could get it to work.',
#  'I have used many other phones before this phone, (HTC M8, M7) Samsung S5... This is by far the best one..Very quick response, and the battery life is so good. I use my phone heavily and I am on wechat the whole day. From 6 am- 10pm there is about 40% left. Screen is clear. I recomment putting a tempered glass screen protector. 5 out of 5.',
#  'Excellet!',
#  'Terrible cheap phone, keep browsing, just not the BLU section!',
#  "It's Good Product But I have small doubt Does it is having warranty?",
#  'Good phone for the price.',
#  'Great',
#  'This phone was a great price, and works as intended. i have always been and android user, this is my first IPhone and it works great. i also love the color.',
#  'Great thabk u',
#  'great phone, good for senior elderly to use, unlocked and affordable and comfortable in the hands.',
#  'Works great',
#  'Not read sim carda',
#  'Battery life sucks but i LOVE the phone',
#  'all perftct',
#  'Good quality with good price!',
#  'Works fine',
#  "Phone is fantastic. Better that jumping into the Galaxy S6 or S6 Edge(+) all the features you need and less the expensive models sell points that you don't need.",
#  'Excellent quality and the product is nice, good seller',
#  'Exellent phone',
#  'So colorful and truly brightens up my phone',
#  'excellent',
#  'fine',
#  "this cell is fine! it's very clear, Perice, and very easy to use. i also bought the plastic clear protective case which is very easy to install, and the slide feature to text works with no problem at all. i recommend this cell to anyone who still wants numbers to dial instead of a touch screen, and you still will be popular with your peers! best.",
#  'Muy bueno',
#  "My phone works well in the US and out of the country. I just pop out the SD card and insert a new one and it works seamlessly. Battery life is pretty good, I can usually make it throughout the day on one charge, and I use my phone heavily. The gold metal surrounding the phone is a beautiful touch. The only thing I don't like is the pop ups that bombard my phone from time to time. I have owned several phones and never experienced this problem.",
#  "I've had the Life View for about a month now and I must say that it has meet and exceeded all expectations. The screen is large and vibrant. The camera takes awesome photos and the sound is top notch, and it works great with my SIM (T-Mobile)! I would highly recommend this phone.",
#  "It didn't meet my expectations. It has numerous issues and will not hold a charge. The battery dies fast.",
#  "This lasted 6 months and because I didn't understand the implications of an international phone, I am stuck. The seller won't help me and neither will Amazon. Don't Buy!",
#  'Good shape. Brand new and perfectly package. Came on time. At the moment, works perfectly and it full feels all my expectations.',
#  'Yes',
#  'Everytime I opened google map， it takes me 20mins to located my position.Except GPS everything is great. Hope BLU could improve GPS',
#  'I AM SATISFIED',
#  "Got for my Verizon account. Lots to love, Pure android and I think more straight forward than my iphone. I put a Beetle case on it and feels substantial. A little biggish for me. The sound might be a little tinny. I had a long load alert for my calendar items on the iphone & outlook, haven't gotten there with the Nexus & Google.",
#  "It's like new!!!! And works so well!!",
#  'Great iPhone -like phone. Purchased a Huawei mate 2 prior to this phone. The functionality of the software the phone build is far better. The colors are rich will buy again',
#  'I Love it. Unlocked as promised, NEW.Works like a charm, battery has a crazy long life with all APPs running normally. I simply love my Windows Phone 8.1 Operating System.Only missing the wireless charger that is sell separately.',
#  "One of the better phones at price value to take advantage of T-Mobile's 700 MHz LTE.",
#  'The phone has problems with the wifi antenna does not work, and the charging connector takes no cargo, equipment battery is discharged very quickly.',
#  "It's hard to meet my expectations but this product did. Arrived fast and safe. So far so good.",
#  "wife couldn't like w/out it!,it doing great...",
#  'Good morning. The two teams that have trouble buying. One is not free and the other has a problem with the touch. How could we solve',
#  'I have the Otterbox for my Lumia 925, so when I bought the Samsung Note 10.1", I didn\'t even consider other manufacturers. The Samsung tablet is very slippery and feels fragile. With the Otterbox, one has room to grip it, and the cats can crawl over it on the bed :-) as one doesn\'t have to fear a screen scratch. Additionally, the back clips off and allows one to clip it onto the front, making for a totally enclosed, rugged, box.After using an Otterbox, there is just nobody else...Hope this helps.',
#  'Great buy!!!!',
#  'feel little too big for my hands....but, tech-wise, always trust windows-phone!! thank you.',
#  "I opened the phone last night. I did not have time since I bought it!? The phone is excellent. The 16Gb memory didn't come with it; although it stated in the purchasing form.It offers everything. No complaints so far.",
#  'Nice phone for the Price.',
#  'Would not charge...returned. Tired of "certified refurbished" items constantly being defective.',
#  'Very early delivery and great quality!',
#  'Thanks',
#  'This is my third SONY phone. Excellent !!! I love this Phone! Everything works on it just fine. I have ATT as carrier i live in the US. Took it to ATT when i received it they put a new sim card in and no problems since. Updated to Marshmallow with no problem. I love it and my kids love it. Thank You!',
#  'Good products',
#  'the phone its good, really fast, came with a 2gb sd memory and only english, but the t-mobile doesnt work 3G movistar venezuela, should have known before the purchase.',
#  "Spend a little more and buy another brand.this is very slow.the first one that i received was a deffect on the display.the second one i used it around 3 months and the start button does't work now.but expired the warranty.",
#  'excellent',
#  "I've been very pleasantly surprised by this phone. My last phone was a Samsung Galaxy S3 and so far this just blows that out of the water. Great, front-facing speakers (for a phone, at least), solid connectivity and web browsing experience, nice sleak design, impressive battery life. It has everything I need in a phone for the right price.",
#  'Great',
#  'I really love my note 3 and the purchase price was great. Delivery time was correct and I had no problem getting it set up for my straight talk account. Amazon great place to order what ever you need and quick delivery.',
#  'nice cell',
#  'Excelente telefono',
#  "It was bad thing,the screen was brokenI don't know if I am going to shop online anymore 😭😭😭😭",
#  'excelent',
#  'Good phone. Had what I requested. Came promptly. No complaints.',
#  'this is definitly a great move from LG. the phone is smooth and the display is just amazing. blazing fast and affordable.',
#  'I love this otter box defender phone cover for my Samsung galaxy S5. The price is awesome considering retail stores want $50 for it. Love the classic dot and navy blue color. Protects my phone from accidental falls, scratches, and dust.',
#  'Excelent',
#  'This phone did not work, we put the sim card in and it would not read it, we tried a different sims card with a different carrier and it still would not read it, this is not as small as it looks in the picture, yes they give you dimensions but who is going to be using a tape measure when they are looking at cell phones, i needed something i could hide very easily when i am at work specifically for emergency calls only, this one was a little too big to hide like that',
#  'Excelent cellphone',
#  'Overall this is a pretty good phone downside is only like 1gb of free space but other than that is good it looks like a $700 phone',
#  "The cellphone's connector got damage, besides the cellphone auto resets all the time. The cellphone has only 3 months.",
#  'Awesome!!!',
#  "Best phone I've ever had, still use it to this day without any issues so far!! Definitely recommend to those who want a phone with pen capabilities and overall awesomeness of Android! Have not even considered moving up to the Note 5 yet, 4 is perfect, and pink! 😁",
#  "Summary: Overall a great phone. Excellent camera and overall responsiveness.I purchased this exclusively to function on Tracfone's Straight Talk network they promote from Walmart. Works perfectly after getting the SIM card installed and setting APN to Straight Talk's.I would have left this at 4 stars before the 8.1 update, however, with Windows Phone 8.1, Microsoft absolutely nailed the quality of life issues I had with the phone. Biggest culprit being integrated playlist creation and editing. Improvement to the lock and start screens also is a big plus.Only con I have right now is that the maps have some issues with GPS location in cities, tends to not get a signal.",
#  'Great phone',
#  "Screen went out in less than three hours of having it. Wouldn't recommend the product.",
#  'Very quick shipping and great quality phone!!',
# ...
#  "Great phone. It's a great bang for your buck deal. I've been impressed with the speed of this phone so far. Every app I've used has run without any issues so far.",
#  'The charger port was broken... it wouldnt charge so i had to charge it thru the old phone in order to charge the battery',
#  'excelente el producto lo recomiendo, llego en buenas condiciones. el empaque es muy bueno, no estaba abierto y a tiempo!!',
#  'Great phone for basic stuff. Checking email, browsing and calls.',
#  'Excellent',
#  'I like it..',
#  "The phone is really good for the price point. However there are three things that are annoying with the phone that other people do not comment on. One is that the text messaging does not work that comes with the phone and you have to download a separate app to make it work properly. The other annoyance is that the phone freezes and resets once in a while. I've read that you can root the phone and after uninstalling the T-Mobile apps the second problem will go away. Lastly 512mb isnt that much memory and unless you know how to clean the memory it may run slow.That said the phone is really great. It is small. I've clocked downloads on T-Mobile as fast as 6-8 megabits per second (depends on where you live). Very customizable and functional. Knowing what I do know now, I would still get the phone as it does get the job done once you download the right apps.I'm sure other apps can solve the problems. These are the ones that I use: go sms pro, Advanced task killer and start up cleaner.",
#  'I love this phone. Unfortunately within the first week of purchasing my daughter dropped it and destroyed the screen, but it still works perfectly. I would definitely recommend this. As a matter of fact my husband is now thinking of purchasing one for himself. I',
#  'Phone came with the battery completely dead abs the lcd screen broken.',
#  'It met my expectations.',
#  'Good product, fast delivery.',
#  'perfecto',
#  'The 5 stars is not because this is the best phone ever... I do however feel it was the best deal for the money. From the little time I have had the phone I do notice the battery, once in use, goes quickly, but for my needs no real issue as I mainly text. Was concerned about problems using a tracfone sim card and the number transfer took a long time but again no hiccups.The phone is clear, runs apps better than my old LG. Hooking my wife up with same right now as early Christmas present. Very impressed so far.',
#  "I am very pleased with my new phone. I was nervous, having only used an iPhone up to this point, but the Xperia app and the cord made to bridge the phones to jump info to the new Xperia made this phone a very worthy replacement for my old iPhone. I couldn't be more pleased. I haven't run down the battery yet, it handles everything I need it to do, and is a very attractive phone. The sound quality is something I was worried about -- worry not! The sound quality is every bit as good as my iPhone was, if not better. The android platform really isn't that hard to get used to on this phone either. I'm already spoiled rotten, no turning back.",
#  'great phone, great quality',
#  "I do not want to be negative. After 5 weeks of using the phone it shows that it is not good. the battery takes more then 4 hours to charge while the phone is off. When I turn it on, it looks like the battery is not fully charged. The phone has now two days that it turn off on it's own. Every time I turn it on, Android is updating. I am disappointed at this product! I feel ripped off and I will never again buy a HTC phone. And will not recommend people to buy one!",
#  "Soon after purchase the screen became pixilated and flickers and eventually went black. Samsung claims they don't cover the international LATAM phones under their product warranty even though it was purchased in the USA for international travel purposes.",
#  "It's a nice android smartwatch I really haven't had time to do a lot of stuff with it yet I would recommend this to you and family and friends too. I still want a lg smartwatch. It's something about the real deal. Later ppl",
#  'exactly what is should be...small phone good ring volume, only wish would be the ability to use any charging cord.',
#  'works Great...Fast shipping. Luv it.',
#  'I ordered 2 phones,and as soon as they arrived they were in horrible conditions,seller promptly sent another 2 phones when I returned the first two,and when these phone got here they were worst then the first 2! No chargers,no batteries,ESN number written in pen inside the phone. Very disappointing!!! I want my money back! Waiting on their response in the matter!',
#  "doesn't work good i want a new one or my money back dont buy this device.",
#  "pretty solid phone. i almost didn't notice that the SD card slides ride above the first SIM card slot. pretty cool. after a year of having a Windows phone, i jumped at the chance to get a Samsung phone with Android. couldn't be happier.",
#  'Amazing phone.',
#  'excelente',
#  'The phone I got is the iphone 7 MN8K2ll/A which is not an unlocked phone but one that is listed as Verizon and locked. The product description said Apple Iphone 7 Unlocked US Version. This is very misleading advertising,UPDATE:Though I have not activated the phone this model recognized the DIgicel SIM and network easily. I upgraded the review to 4 stars',
#  'I previously posted a negative review, so I hope that this one is posted. Device was adequate at best when received. Now it intermittently skips portions of the signal so that I hear about 2-3 seconds, and then it skips 2-3 seconds. Tech support said it was probably my service provider. I pointed out that I was talking to them on another phone using the same service provider, and they finally agreed that the problem was "probably" the phone. Solution is to send it to them, and they will repair it in 7-10 days and ship it back. The tech support person assured me that my provider would provide a temp phone for me to use. Since this is not a SW Bell phone, I seriously doubt that will happen!',
#  'Everything ok',
#  "For some reason, you guys sent me an European version, it has worked good until now, but I don't know if it will cause me any trouble in the future. Also I can't charge it because the charger that came with the phone is designed for Europe.",
#  'This more than met my expectations!! Amazon is great for customers finding deals that live up to high standards with virtually no risk to the consumer!!',
#  "This is an excellent phone for the price. The screen is lovely, and the overall speed of the phone is excellent. You can update it to Android Marshmallow out of the box.It's surprisingly manageable, for the size, also, and I've found the battery life to be perfectly acceptable, if not amazing. It's better than the 1st gen Moto X it replaced. Also, it charges super fast (unlike Oneplus 2, which has no fast charging, despite its fancy USB C port...). The home button doubling as a notification light is also nice, in my opinion- a pleasant surprise. The software is almost stock Android, with some minor changes.The camera is quite nice. It doesn't always take great indoor shoes, but Bokeh mode is very fun, and looks great, in my opinion. While I wish it had OIS, the camera software is quite robust. There are a ton of settings that you can tweak.Heat has not been a problem (despite the 810s reputation). Especially with a cover on it, I'm not even noticing it getting warm under normal use.Only negatives so far: The top speaker (the one that you put up to your ear) has the cutout on the right side of the phone, meaning that, if you center the earpiece on your ear, the sound is low. You have to put the right side up to your ear to hear clearly when holding in your right hand, and vice versa. For someone who wears glasses, it means that the phone bumps into them when in my right hand, which is a minor annoyance.Also, I wish the camera button was two-stage, so that it would refocus on demand. (Still, a double tap launches the camera, and the automatic focus is pretty quick, so that's something).Lastly, there are some minor software annoyances. The clock has the appearance of stock Android, but it's baked into their weather/clock widget, and seems to be stuck at version 3.1. I just disabled it and installed the Google one from the Play Store, as I prefer to use WeatherBug anyway. Also, the notification light wasn't enabled by default, so I had to search for the setting to turn it on.There are other things that I could count as negatives but, given the price, I think they're acceptable (no fingerprint scanner, no SD card slot). To me, the Oneplus 2 loses to this phone at this price, due to the lack of QHD screen, fast charging and NFC, as I believe phones for payments will only become more common over the next year.",
#  'Working fine so far.',
#  "The phone works great my husband likes it just fine not the charger I thought was coming with it but it's fine too",
#  'I purchased this unlocked for a move overseas and am not putting as SD card in it until I arrive in S America in 6 weeks. So far it powers up and the screen is bright. I will try to update review later. I love that it has a removable battery.',
#  'This phone is crap, it fails to stay backlit, fails to retain phone numbers and other data. Whom ever designed the workings of this phone did not know what they were doing, it a far cry from my original RAZAR. DO NOT BUY THIS PRODUCT!',
#  'WOW I feel like I got the. Best deal ever phone is & works perfectly no issues at all',
#  'Work Perfectly',
#  'Good',
#  'goog',
#  'all that i wanted best purchase ive made money well spent does everything it says n even more definately a best buy',
#  'Good excellent salesman equipment, the purchase I am realised without disadvantages, the equipment this in perfect conditions for its use. Thanks',
#  'I ordered this phone twice trying to give it a second chance because I was getting it as a gift. The first time I ordered this the phone came in a used box with the HTC sticker and an iPhone 4 sticker. Not only this, but the box contained a used iPhone 4!!!! I was extremely disappointed. The second time I ordered the phone the box was empty! Please be aware, there seems to be people who have had great experiences though.',
#  "Blanks in and out when talking. No storage and slow internet connection . Can't find many accessories. Battery life is low",
#  "This Blackberry is not in English, all Spanish. Even the user's guide is in the Spanish language and hard to change over to English. Called the seller and was told this model was for Latin America only. They should let us English speakers know before we buy.",
#  'This is a great phone at a great price.',
#  "Second one I've had. Protects your phone well. Only thing to be careful about is the covers for the charger and headphones can break off over time which will allow dust to get in.",
#  'The box has sigh of open and bang.The phone itself is ok. The back cover does not close completely. It keeps popping out.I am tmobile. It took me 2 weeks to get some apps working. I still cannot get rid of AT&T stuffs.',
#  'Great phone, unlocked as advertised. Is fast and easy to use. I recommend',
#  'Extremely misleading. This phone is only compatible with a European SIM card. The description does mention that it is not originally intended for use in the states, but does not even come close to mentioning that it is completely incompatible. Do not buy for use in the US. I read the description thoroughly and repeatedly and was still not prepared for what I received.',
#  'Battery dies very fast- this was a mistake!! I have to suspect that the new units with battery draining in a few hours are not new or are units with manufacturing defects.',
#  "This device really is well constructed and when in the hand you can feel the excellent build quality. The key issue with BlackBerry is the lack of apps in the BlackBerry App store. But you can easily side step that via the Cobalt plug ins which allow you to install the Google Play Store and most Google Apps. Most of the other reviews haven spoken about the keyboard etc. So I won't rehash those but I must say I expected a bit more from the battery given its size. I currently get 15-20 hrs with mixed use. I also notice some warming in the top right corner of the phone once you have restarted the device or have a power hungry app running.But overall I'm impressed with the phone.",
#  "Great, inexpensive, alternative to the more expensive smartphones. I paid around $40 for this and I think it was a fantastic deal. For the price, this smartphone is great. For me, there are 2 downsides: 1) video quality & 2) the back cover. The video quality (and even zooming in on pictures) is definately less than par. Video is dark, slightly distorted and pic quality (zoomed in) becomes blurry. The other, the back cover, comes off the phone so easy. If you drop the phone, chances are the cover will come off. I actually dropped my phone, the back cover came off, and upon impact my battery fell out and broke. Otherwise, a great phone. And, for the price, you can't beat it.",
#  'Very nice phone, I purchased another one.',
#  "Great phone - my daughter loves it! She on it all the time - in mom's opinion too much.",
#  'Do not purchase this phone! You will be sending your money to waste. I bought mine over a month ago and it is no longer working. It will not respond to any of my commands. It is acting like it has a mind of its own. The camera stopped working first then the entire phone when out. I was only a few days over the 30 day policy and could not return it.',
#  "Broke within two weeks and couldn't turn it back on!! Also time zone was stuck on Austria!!!!",
#  'Absolutely love it!',
#  "I am extremely satisfied with this phone even if it's not the latest Tab. I purchased this phone because it was unlocked, under $300, and it has a screen size that accommodates my thick fingers. The phone arrived brand new and with the latest version of android available from Samsung for this model.",
#  "I love this phone. It's fun and has everything I need and more in a cell phone. It took a bit to get used to the stylus but it was so great I got the Note Tablet too.",
#  'I love it. It came really fast and is in perfect condition. Side Note: There may be a screen protector on the device that may look a little worn.',
#  "Unfortunately, this item did not come quite as promised. It's in great condition, no question, but it arrived without a sim card. It was a gift and when I gave it to my son, he discovered the sim card was missing and took the one from his old iPhone 5 and put it in this one. This phone does not hold a charge and doesn't always work as it should. The Verizon staff told us that often when a phone arrives without a sim card (and this one was supposed to have been a Verizon phone, it is often stolen. I hope that isn't the case with this one, but either way, I'm pretty disappointed that I spent $176.00 on a phone that didn't arrive the way it was promised, and doesn't work properly.",
#  'I paid $ 799 got a phone is a real doll This is very Masef',
#  'as described. good value',
#  'OK',
#  'This is an excellent product... a well cellphone',
#  'Perfect for my mom. I really like the emergency feature and I linked it to my phone so it notifies me whenever my mom calls the emergency service',
#  'excelent phone, work without problems in Ecuador',
#  'This is a nice phone with all the basic features one expects from a smart phone. The first one I purchased had problems: about once a week, the phone would cycle power in the middle of a phone conversation. Reading online, this seems to be a systematic problem (hardware?) to which there was no easy solution. After 3 weeks, requested a replacement from Amazon. Two weeks now and there has been no problems.So if you see similar problems, be quick to get a replacement. Otherwise it is a nice phone.',
#  'Phone worked perfectly with minimal scratches. Very Satisfied.',
#  ...]

# %% [markdown]
# # CountVectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Fit the CountVectorizer to the training data
vect = CountVectorizer().fit(X_train)

# %%
vect.get_feature_names()[::2000]
# Out:
# ['00',
#  'arroja',
#  'comapañias',
#  'dvds',
#  'golden',
#  'lands',
#  'oil',
#  'razonable',
#  'smallsliver',
#  'tweak']

# %%
len(vect.get_feature_names())
# Out:
# 19601

# %%
# transform the documents in the training data to a document-term matrix
X_train_vectorized = vect.transform(X_train)

X_train_vectorized
# Out:
# <23052x19601 sparse matrix of type '<class 'numpy.int64'>'
# 	with 613289 stored elements in Compressed Sparse Row format>

# %%
from sklearn.linear_model import LogisticRegression

# Train the model
model = LogisticRegression()
model.fit(X_train_vectorized, y_train)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
from sklearn.metrics import roc_auc_score

# Predict the transformed test documents
predictions = model.predict(vect.transform(X_test))

print('AUC: ', roc_auc_score(y_test, predictions))
# Out:
# AUC:  0.8963986165184588

# %%
# get the feature names as numpy array
feature_names = np.array(vect.get_feature_names())

# Sort the coefficients from the model
sorted_coef_index = model.coef_[0].argsort()

# Find the 10 smallest and 10 largest coefficients
# The 10 largest coefficients are being indexed using [:-11:-1] 
# so the list returned is in order of largest to smallest
print('Smallest Coefs:\n{}\n'.format(feature_names[sorted_coef_index[:10]]))
print('Largest Coefs: \n{}'.format(feature_names[sorted_coef_index[:-11:-1]]))
# Out:
# Smallest Coefs:
# ['worst' 'terrible' 'slow' 'junk' 'waste' 'sucks' 'poor' 'useless'
#  'disappointed' 'horrible']
#
# Largest Coefs:
# ['excelent' 'excellent' 'excelente' 'perfectly' 'love' 'perfect' 'exactly'
#  'great' 'best' 'awesome']

# %% [markdown]
# # Tfidf

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Fit the TfidfVectorizer to the training data specifiying a minimum document frequency of 5
vect = TfidfVectorizer(min_df=5).fit(X_train)
len(vect.get_feature_names())
# Out:
# 5442

# %%
X_train_vectorized = vect.transform(X_train)

model = LogisticRegression()
model.fit(X_train_vectorized, y_train)

predictions = model.predict(vect.transform(X_test))

print('AUC: ', roc_auc_score(y_test, predictions))
# Out:
# AUC:  0.889951006492175

# %%
feature_names = np.array(vect.get_feature_names())

sorted_tfidf_index = X_train_vectorized.max(0).toarray()[0].argsort()

print('Smallest tfidf:\n{}\n'.format(feature_names[sorted_tfidf_index[:10]]))
print('Largest tfidf: \n{}'.format(feature_names[sorted_tfidf_index[:-11:-1]]))
# Out:
# Smallest tfidf:
# ['61' 'printer' 'approach' 'adjustment' 'consequences' 'length' 'emailing'
#  'degrees' 'handsfree' 'chipset']
#
# Largest tfidf:
# ['unlocked' 'handy' 'useless' 'cheat' 'up' 'original' 'exelent' 'exelente'
#  'exellent' 'satisfied']

# %%
sorted_coef_index = model.coef_[0].argsort()

print('Smallest Coefs:\n{}\n'.format(feature_names[sorted_coef_index[:10]]))
print('Largest Coefs: \n{}'.format(feature_names[sorted_coef_index[:-11:-1]]))
# Out:
# Smallest Coefs:
# ['not' 'slow' 'disappointed' 'worst' 'terrible' 'never' 'return' 'doesn'
#  'horrible' 'waste']
#
# Largest Coefs:
# ['great' 'love' 'excellent' 'good' 'best' 'perfect' 'price' 'awesome'
#  'far' 'perfectly']

# %%
# These reviews are treated the same by our current model
print(model.predict(vect.transform(['not an issue, phone is working',
                                    'an issue, phone is not working'])))
# Out:
# [0 0]

# %% [markdown]
# # n-grams

# %%
# Fit the CountVectorizer to the training data specifiying a minimum 
# document frequency of 5 and extracting 1-grams and 2-grams
vect = CountVectorizer(min_df=5, ngram_range=(1,2)).fit(X_train)

X_train_vectorized = vect.transform(X_train)

len(vect.get_feature_names())
# Out:
# 29072

# %%
model = LogisticRegression()
model.fit(X_train_vectorized, y_train)

predictions = model.predict(vect.transform(X_test))

print('AUC: ', roc_auc_score(y_test, predictions))
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# AUC:  0.9104640361714084

# %%
feature_names = np.array(vect.get_feature_names())

sorted_coef_index = model.coef_[0].argsort()

print('Smallest Coefs:\n{}\n'.format(feature_names[sorted_coef_index[:10]]))
print('Largest Coefs: \n{}'.format(feature_names[sorted_coef_index[:-11:-1]]))
# Out:
# Smallest Coefs:
# ['no good' 'junk' 'poor' 'slow' 'worst' 'broken' 'not good' 'terrible'
#  'defective' 'horrible']
#
# Largest Coefs:
# ['excellent' 'excelente' 'perfect' 'excelent' 'great' 'love' 'awesome'
#  'no problems' 'good' 'best']

# %%
# These reviews are now correctly identified
print(model.predict(vect.transform(['not an issue, phone is working',
                                    'an issue, phone is not working'])))
# Out:
# [1 0]
